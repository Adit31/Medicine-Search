# %%
import json
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize

# %%
file = open("medicine_dataset.json")
data = json.load(file)

# %%
df = pd.json_normalize(data['results'])

# %%
df.head(5)
# Out:
#   marketing_start_date             product_type  \
# 0             20021126  HUMAN PRESCRIPTION DRUG
# 1             20200615           HUMAN OTC DRUG
# 2             20200201           HUMAN OTC DRUG
# 3             20200503           HUMAN OTC DRUG
# 4             20200429           HUMAN OTC DRUG
#
#                                        product_id       marketing_category  \
# 0  0002-3227_bef991ff-4775-4854-94c1-88081bbf9354                      NDA
# 1  73517-127_a7c0e064-6a7e-1c11-e053-2995a90a7809  OTC MONOGRAPH NOT FINAL
# 2  73528-400_984816e3-3097-44c6-e053-2995a90af1aa      OTC MONOGRAPH FINAL
# 3  73549-003_a59c626f-6ddd-b8bb-e053-2995a90a170f  OTC MONOGRAPH NOT FINAL
# 4  73557-235_a4734fbc-6b68-3d12-e053-2a95a90a3838  OTC MONOGRAPH NOT FINAL
#
#        route               generic_name                brand_name  \
# 0     [ORAL]  Atomoxetine hydrochloride                 Strattera
# 1  [TOPICAL]                    ALCOHOL  Biossance Hand Sanitizer
# 2  [TOPICAL]            Zinc Pyrithione                 Treatment
# 3  [TOPICAL]              Hand Cleanser             Hand Cleanser
# 4  [TOPICAL]     Alcohol Hand Sanitizer    INSTANT HAND SANITIZER
#
#             brand_name_base                                labeler_name  \
# 0                 Strattera                       Eli Lilly and Company
# 1  Biossance Hand Sanitizer                                 Amyris, Inc
# 2                 Treatment                       No Flakes Given, LLC.
# 3             Hand Cleanser                    Fortress Expert Co., Ltd
# 4    INSTANT HAND SANITIZER  Shanghai Chuangshi Industry Group Co., Ltd
#
#                                            packaging  ...  \
# 0  [{'marketing_start_date': '20030110', 'sample'...  ...
# 1  [{'marketing_start_date': '20200615', 'sample'...  ...
# 2  [{'marketing_start_date': '20200201', 'sample'...  ...
# 3  [{'marketing_start_date': '20200503', 'sample'...  ...
# 4  [{'marketing_start_date': '20200429', 'sample'...  ...
#
#                                          openfda.upc  \
# 0  [0300023229304, 0300023228307, 0300023238306, ...
# 1                                                NaN
# 2                                                NaN
# 3                     [6973078420299, 0081261000084]
# 4      [6924239702617, 6924239750328, 6924239750342]
#
#   openfda.is_original_packager  marketing_end_date dea_schedule  \
# 0                       [True]                 NaN          NaN
# 1                       [True]                 NaN          NaN
# 2                       [True]                 NaN          NaN
# 3                       [True]                 NaN          NaN
# 4                       [True]                 NaN          NaN
#
#   brand_name_suffix openfda.pharm_class_cs openfda.pharm_class_epc  \
# 0               NaN                    NaN                     NaN
# 1               NaN                    NaN                     NaN
# 2               NaN                    NaN                     NaN
# 3               NaN                    NaN                     NaN
# 4               NaN                    NaN                     NaN
#
#   openfda.nui openfda.pharm_class_pe openfda.pharm_class_moa
# 0         NaN                    NaN                     NaN
# 1         NaN                    NaN                     NaN
# 2         NaN                    NaN                     NaN
# 3         NaN                    NaN                     NaN
# 4         NaN                    NaN                     NaN
#
# [5 rows x 32 columns]

# %%
def flatten_json(nested_json, exclude=['']):
    out = {}

    def flatten(x, name='', exclude=exclude):
        if type(x) is dict:
            for a in x:
                if a not in exclude: flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(nested_json)
    return out

# %%
new_df = pd.DataFrame([flatten_json(x) for x in data['results']])

# %%
new_df1 = new_df[['product_type','product_id','marketing_category','generic_name','brand_name','brand_name_base','labeler_name','active_ingredients_0_strength','active_ingredients_0_name']].copy()

# %%
new_df1.head()
# Out:
#               product_type                                      product_id  \
# 0  HUMAN PRESCRIPTION DRUG  0002-3227_bef991ff-4775-4854-94c1-88081bbf9354
# 1           HUMAN OTC DRUG  73517-127_a7c0e064-6a7e-1c11-e053-2995a90a7809
# 2           HUMAN OTC DRUG  73528-400_984816e3-3097-44c6-e053-2995a90af1aa
# 3           HUMAN OTC DRUG  73549-003_a59c626f-6ddd-b8bb-e053-2995a90a170f
# 4           HUMAN OTC DRUG  73557-235_a4734fbc-6b68-3d12-e053-2a95a90a3838
#
#         marketing_category               generic_name  \
# 0                      NDA  Atomoxetine hydrochloride
# 1  OTC MONOGRAPH NOT FINAL                    ALCOHOL
# 2      OTC MONOGRAPH FINAL            Zinc Pyrithione
# 3  OTC MONOGRAPH NOT FINAL              Hand Cleanser
# 4  OTC MONOGRAPH NOT FINAL     Alcohol Hand Sanitizer
#
#                  brand_name           brand_name_base  \
# 0                 Strattera                 Strattera
# 1  Biossance Hand Sanitizer  Biossance Hand Sanitizer
# 2                 Treatment                 Treatment
# 3             Hand Cleanser             Hand Cleanser
# 4    INSTANT HAND SANITIZER    INSTANT HAND SANITIZER
#
#                                  labeler_name active_ingredients_0_strength  \
# 0                       Eli Lilly and Company                       10 mg/1
# 1                                 Amyris, Inc                   70 mL/100mL
# 2                       No Flakes Given, LLC.                  .125 g/100mL
# 3                    Fortress Expert Co., Ltd                   76 mL/100mL
# 4  Shanghai Chuangshi Industry Group Co., Ltd               168.75 mL/225mL
#
#    active_ingredients_0_name
# 0  ATOMOXETINE HYDROCHLORIDE
# 1                    ALCOHOL
# 2            PYRITHIONE ZINC
# 3                    ALCOHOL
# 4                    ALCOHOL

# %%
np.random.seed(42)
new_df1['price'] = np.random.randint(50,4500,new_df1.shape[0])

# %%
new_df1.head()
# Out:
#               product_type                                      product_id  \
# 0  HUMAN PRESCRIPTION DRUG  0002-3227_bef991ff-4775-4854-94c1-88081bbf9354
# 1           HUMAN OTC DRUG  73517-127_a7c0e064-6a7e-1c11-e053-2995a90a7809
# 2           HUMAN OTC DRUG  73528-400_984816e3-3097-44c6-e053-2995a90af1aa
# 3           HUMAN OTC DRUG  73549-003_a59c626f-6ddd-b8bb-e053-2995a90a170f
# 4           HUMAN OTC DRUG  73557-235_a4734fbc-6b68-3d12-e053-2a95a90a3838
#
#         marketing_category               generic_name  \
# 0                      NDA  Atomoxetine hydrochloride
# 1  OTC MONOGRAPH NOT FINAL                    ALCOHOL
# 2      OTC MONOGRAPH FINAL            Zinc Pyrithione
# 3  OTC MONOGRAPH NOT FINAL              Hand Cleanser
# 4  OTC MONOGRAPH NOT FINAL     Alcohol Hand Sanitizer
#
#                  brand_name           brand_name_base  \
# 0                 Strattera                 Strattera
# 1  Biossance Hand Sanitizer  Biossance Hand Sanitizer
# 2                 Treatment                 Treatment
# 3             Hand Cleanser             Hand Cleanser
# 4    INSTANT HAND SANITIZER    INSTANT HAND SANITIZER
#
#                                  labeler_name active_ingredients_0_strength  \
# 0                       Eli Lilly and Company                       10 mg/1
# 1                                 Amyris, Inc                   70 mL/100mL
# 2                       No Flakes Given, LLC.                  .125 g/100mL
# 3                    Fortress Expert Co., Ltd                   76 mL/100mL
# 4  Shanghai Chuangshi Industry Group Co., Ltd               168.75 mL/225mL
#
#    active_ingredients_0_name  price
# 0  ATOMOXETINE HYDROCHLORIDE    910
# 1                    ALCOHOL   3822
# 2            PYRITHIONE ZINC   3142
# 3                    ALCOHOL    516
# 4                    ALCOHOL   4476

# %%
new_df1.shape
# Out:
# (129322, 10)

# %%
new_df1 = new_df1.dropna( how = 'any', axis = 0)

# %%
new_df1.shape
# Out:
# (109512, 10)

# %%
new_df1.describe()
# Out:
#                price
# count  109512.000000
# mean     2270.965839
# std      1285.354822
# min        50.000000
# 25%      1156.000000
# 50%      2271.000000
# 75%      3382.000000
# max      4499.000000

# %%
new_df1 = new_df1.sort_values("price")

# %%
new_df1.reset_index(inplace = True, drop = True)

# %%
new_df1.head()
# Out:
#               product_type                                       product_id  \
# 0  HUMAN PRESCRIPTION DRUG   0409-5086_f6853103-2302-4a43-81cf-a2058e04aba8
# 1           HUMAN OTC DRUG   71447-300_9a1184f5-64d7-9786-e053-2a95a90a03b8
# 2           HUMAN OTC DRUG   77046-003_a844577c-c1b3-0d44-e053-2a95a90a82cf
# 3  HUMAN PRESCRIPTION DRUG  55154-8285_770eefdf-ad77-48cd-a209-b179dc11eede
# 4           HUMAN OTC DRUG  60905-0825_8c4da38f-6373-fc7a-e053-2995a90a17ee
#
#         marketing_category                  generic_name  \
# 0                     ANDA                   CEFTAZIDIME
# 1      OTC MONOGRAPH FINAL                        KAOLIN
# 2  OTC MONOGRAPH NOT FINAL                      wet wipe
# 3                     ANDA                     Clozapine
# 4  OTC MONOGRAPH NOT FINAL  OCTINOXATE, TITANIUM DIOXIDE
#
#                                           brand_name  \
# 0                                            TAZICEF
# 1                     DRUIDE BIOLOVE FOR DIAPER RASH
# 2                               HAND SANITIZER WIPES
# 3                                          Clozapine
# 4  TEINT COUTURE EVERWEAR 24h Wear Satin Finish F...
#
#                                      brand_name_base  \
# 0                                            TAZICEF
# 1                     DRUIDE BIOLOVE FOR DIAPER RASH
# 2                               HAND SANITIZER WIPES
# 3                                          Clozapine
# 4  TEINT COUTURE EVERWEAR 24h Wear Satin Finish F...
#
#                           labeler_name active_ingredients_0_strength  \
# 0                        Hospira, Inc.                         6 g/1
# 1              LABORATOIRES DRUIDE INC                      4 g/100g
# 2  ZHEJIANG HUASHUN TECHNOLOGY CO.,LTD                     .1 g/100g
# 3                      Cardinal Health                      100 mg/1
# 4                LVMH FRAGRANCE BRANDS                      30 mg/mL
#
#   active_ingredients_0_name  price
# 0               CEFTAZIDIME     50
# 1                    KAOLIN     50
# 2     BENZALKONIUM CHLORIDE     50
# 3                 CLOZAPINE     50
# 4                OCTINOXATE     50

# %%
new_df1.to_csv("clean_medicine_data.csv")
