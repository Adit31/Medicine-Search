# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("clean_medicine_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0             product_type  \
# 0           0  HUMAN PRESCRIPTION DRUG
# 1           1           HUMAN OTC DRUG
# 2           2           HUMAN OTC DRUG
# 3           3  HUMAN PRESCRIPTION DRUG
# 4           4           HUMAN OTC DRUG
#
#                                         product_id       marketing_category  \
# 0   0409-5086_f6853103-2302-4a43-81cf-a2058e04aba8                     ANDA
# 1   71447-300_9a1184f5-64d7-9786-e053-2a95a90a03b8      OTC MONOGRAPH FINAL
# 2   77046-003_a844577c-c1b3-0d44-e053-2a95a90a82cf  OTC MONOGRAPH NOT FINAL
# 3  55154-8285_770eefdf-ad77-48cd-a209-b179dc11eede                     ANDA
# 4  60905-0825_8c4da38f-6373-fc7a-e053-2995a90a17ee  OTC MONOGRAPH NOT FINAL
#
#                    generic_name  \
# 0                   CEFTAZIDIME
# 1                        KAOLIN
# 2                      wet wipe
# 3                     Clozapine
# 4  OCTINOXATE, TITANIUM DIOXIDE
#
#                                           brand_name  \
# 0                                            TAZICEF
# 1                     DRUIDE BIOLOVE FOR DIAPER RASH
# 2                               HAND SANITIZER WIPES
# 3                                          Clozapine
# 4  TEINT COUTURE EVERWEAR 24h Wear Satin Finish F...
#
#                                      brand_name_base  \
# 0                                            TAZICEF
# 1                     DRUIDE BIOLOVE FOR DIAPER RASH
# 2                               HAND SANITIZER WIPES
# 3                                          Clozapine
# 4  TEINT COUTURE EVERWEAR 24h Wear Satin Finish F...
#
#                           labeler_name active_ingredients_0_strength  \
# 0                        Hospira, Inc.                         6 g/1
# 1              LABORATOIRES DRUIDE INC                      4 g/100g
# 2  ZHEJIANG HUASHUN TECHNOLOGY CO.,LTD                     .1 g/100g
# 3                      Cardinal Health                      100 mg/1
# 4                LVMH FRAGRANCE BRANDS                      30 mg/mL
#
#   active_ingredients_0_name  price
# 0               CEFTAZIDIME     50
# 1                    KAOLIN     50
# 2     BENZALKONIUM CHLORIDE     50
# 3                 CLOZAPINE     50
# 4                OCTINOXATE     50

# %%
df.rename( columns = {'Unnamed: 0': 'index', 'active_ingredients_0_strength': 'ingredient_strength', 'active_ingredients_0_name': 'ingredient_name'}, inplace = True)

# %%
df.head()
# Out:
#    index             product_type  \
# 0      0  HUMAN PRESCRIPTION DRUG
# 1      1           HUMAN OTC DRUG
# 2      2           HUMAN OTC DRUG
# 3      3  HUMAN PRESCRIPTION DRUG
# 4      4           HUMAN OTC DRUG
#
#                                         product_id       marketing_category  \
# 0   0409-5086_f6853103-2302-4a43-81cf-a2058e04aba8                     ANDA
# 1   71447-300_9a1184f5-64d7-9786-e053-2a95a90a03b8      OTC MONOGRAPH FINAL
# 2   77046-003_a844577c-c1b3-0d44-e053-2a95a90a82cf  OTC MONOGRAPH NOT FINAL
# 3  55154-8285_770eefdf-ad77-48cd-a209-b179dc11eede                     ANDA
# 4  60905-0825_8c4da38f-6373-fc7a-e053-2995a90a17ee  OTC MONOGRAPH NOT FINAL
#
#                    generic_name  \
# 0                   CEFTAZIDIME
# 1                        KAOLIN
# 2                      wet wipe
# 3                     Clozapine
# 4  OCTINOXATE, TITANIUM DIOXIDE
#
#                                           brand_name  \
# 0                                            TAZICEF
# 1                     DRUIDE BIOLOVE FOR DIAPER RASH
# 2                               HAND SANITIZER WIPES
# 3                                          Clozapine
# 4  TEINT COUTURE EVERWEAR 24h Wear Satin Finish F...
#
#                                      brand_name_base  \
# 0                                            TAZICEF
# 1                     DRUIDE BIOLOVE FOR DIAPER RASH
# 2                               HAND SANITIZER WIPES
# 3                                          Clozapine
# 4  TEINT COUTURE EVERWEAR 24h Wear Satin Finish F...
#
#                           labeler_name ingredient_strength  \
# 0                        Hospira, Inc.               6 g/1
# 1              LABORATOIRES DRUIDE INC            4 g/100g
# 2  ZHEJIANG HUASHUN TECHNOLOGY CO.,LTD           .1 g/100g
# 3                      Cardinal Health            100 mg/1
# 4                LVMH FRAGRANCE BRANDS            30 mg/mL
#
#          ingredient_name  price
# 0            CEFTAZIDIME     50
# 1                 KAOLIN     50
# 2  BENZALKONIUM CHLORIDE     50
# 3              CLOZAPINE     50
# 4             OCTINOXATE     50

# %%
dict_val = {}
columns = list(df)
for column_name in columns:
    if column_name == 'ingredient_name':
        for i in range(0,df.shape[0]):
            if df[column_name][i] not in dict_val.keys():
                index_list = []
                index_list.append(i)
                dict_val[df[column_name][i]] = index_list
            else:
                dict_val[df[column_name][i]].append(i)
    else:
        continue

# %%
def print_salt_search(user_search):
    if user_search in dict_val.keys():
        j = 0
        for i in range(0,len(dict_val[user_search])):
            index = dict_val[user_search][i]
            print(df.loc[index])
            print("")
            j = j + 1
            if j > 5:
                ans = input("do you want to see more results? (Yes/No) : ")
                ans.lower()
                if ans == 'no':
                    break
                else:
                    j = 0
                    continue
    else:
        print("Please enter the complete name to search")
        for salt,index in dict_val.items():
            if user_search in salt:
                j = 0
                for i in range(0,len(dict_val[salt])):
                    index = dict_val[salt][i]
                    print(df.loc[index])
                    print("")
                    j = j + 1
                    if j > 5:
                        break

# %%
def print_med_search(user_search):
    flag = 0
    for i in range(0,df.shape[0]):
        if user_search == df['brand_name'][i]:
            salt_present = df['ingredient_name'][i]
            flag = 1
            break
    if flag == 0:
        print("not found in the database, please try again!")
    else:
        print_salt_search(salt_present)

# %%
user_choice = input("1. Enter the salt whose alternatives you want to check : \n 2. Enter the medicine brand name whose alternatives you want to check :\n")
if user_choice == '1':
    user_search = input("Enter the salt name : ")
    print_salt_search(user_search.upper())
elif user_choice == '2':
    user_search = input("Enter the medicine name : ")
    print_med_search(user_search)
else:
    print("Enter a valid choice")
# Out:
# 1. Enter the salt whose alternatives you want to check :
#  2. Enter the medicine brand name whose alternatives you want to check :
# 2
# Enter the medicine name : Zinc Met
# index                                                            4985
# product_type                                           HUMAN OTC DRUG
# product_id             0220-5433_857e92e8-3987-34b7-e053-2991aa0a72ba
# marketing_category                             UNAPPROVED HOMEOPATHIC
# generic_name                                                     ZINC
# brand_name                                          ZINCUM METALLICUM
# brand_name_base                                     ZINCUM METALLICUM
# labeler_name                                                   Boiron
# ingredient_strength                                  6 [hp_C]/6[hp_C]
# ingredient_name                                                  ZINC
# price                                                             251
# Name: 4985, dtype: object
#
# index                                                            7581
# product_type                                           HUMAN OTC DRUG
# product_id             0220-5436_853c03ff-e1e7-08d0-e053-2a91aa0a9dba
# marketing_category                             UNAPPROVED HOMEOPATHIC
# generic_name                                                     ZINC
# brand_name                                          ZINCUM METALLICUM
# brand_name_base                                     ZINCUM METALLICUM
# labeler_name                                                   Boiron
# ingredient_strength                                15 [hp_C]/15[hp_C]
# ingredient_name                                                  ZINC
# price                                                             355
# Name: 7581, dtype: object
#
# index                                                            7646
# product_type                                           HUMAN OTC DRUG
# product_id             0360-0395_7d7ce2cf-0cbc-e685-e053-2991aa0a4b15
# marketing_category                             UNAPPROVED HOMEOPATHIC
# generic_name                                                 ZINC MET
# brand_name                                          ZINCUM METALLICUM
# brand_name_base                                     ZINCUM METALLICUM
# labeler_name                             STANDARD HOMEOPATHIC COMPANY
# ingredient_strength                                       30 [hp_X]/g
# ingredient_name                                                  ZINC
# price                                                             357
# Name: 7646, dtype: object
#
# index                                                            8493
# product_type                                           HUMAN OTC DRUG
# product_id             68428-712_75e4fb80-8cbe-6449-e053-2a91aa0a533b
# marketing_category                             UNAPPROVED HOMEOPATHIC
# generic_name                                                     ZINC
# brand_name                                          Zincum metallicum
# brand_name_base                                     Zincum metallicum
# labeler_name                          Washington Homeopathic Products
# ingredient_strength                                       30 [hp_C]/1
# ingredient_name                                                  ZINC
# price                                                             393
# Name: 8493, dtype: object
#
# index                                                           17284
# product_type                                           HUMAN OTC DRUG
# product_id             0220-5440_85276a06-7e36-2546-e053-2a91aa0a25ec
# marketing_category                             UNAPPROVED HOMEOPATHIC
# generic_name                                                     ZINC
# brand_name                                          ZINCUM METALLICUM
# brand_name_base                                     ZINCUM METALLICUM
# labeler_name                                                   Boiron
# ingredient_strength                                30 [hp_X]/30[hp_X]
# ingredient_name                                                  ZINC
# price                                                             744
# Name: 17284, dtype: object
#
# index                                                            18041
# product_type                                            HUMAN OTC DRUG
# product_id             44911-0176_bfaa6ffd-1cbe-44bf-97cb-9211f6c345d6
# marketing_category                              UNAPPROVED HOMEOPATHIC
# generic_name                                         Zincum metallicum
# brand_name                                                    Zinc Met
# brand_name_base                                               Zinc Met
# labeler_name                                           Energique, Inc.
# ingredient_strength                                       30 [hp_X]/mL
# ingredient_name                                                   ZINC
# price                                                              775
# Name: 18041, dtype: object
#
# do you want to see more results? (Yes/No) : no
